# %% [markdown]
# # Preparation

# %%
# Input Here

import pandas as pd

QUIZ_DF = pd.read_csv("ProgrammingforDataScienceandPracticalStatistics-all_0.csv") # Quiz CSV Path

SCORE_ACADEMY_LINK = 'https://docs.google.com/spreadsheets/d/1cGJ0pn9k9gKCBnceWVwaL9D7BBDMNjLh8uPYlaBlJi8/edit?usp=sharing' # Score Academy Link
NAMA_SHEET = "Copy of Xion DA" # Sheet Name (Wizard)

# %% [markdown]
# Import required dependencies to use Google's API

# %%
import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# %% [markdown]
# Define the accesses to be granted

# %%
SCOPES = ['https://www.googleapis.com/auth/classroom.courses.readonly', # View your Google Classroom classes.
          'https://www.googleapis.com/auth/classroom.rosters', # Manage your Google Classroom class rosters.
          'https://www.googleapis.com/auth/classroom.profile.emails', # View the email addresses of people in your classes.
          'https://www.googleapis.com/auth/classroom.topics', #See, create, and edit topics in Google Classroom.
          'https://www.googleapis.com/auth/classroom.coursework.students', # Manage coursework and grades for students
          'https://www.googleapis.com/auth/classroom.courseworkmaterials', # See, edit, and create classwork materials in Google Classroom.
          'https://www.googleapis.com/auth/spreadsheets'] # See all your Google Sheets spreadsheets.

# %% [markdown]
# Use the provided `token.json` file to authenticate and access user data, if `token.json` is not available, it would be created from the provided `credentials.json` by logging into user's Google Account

# %%
creds = None

if os.path.exists('token.json'):
    creds = Credentials.from_authorized_user_file('token.json', SCOPES)
# If there are no (valid) credentials available, let the user log in.
if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
        creds.refresh(Request())
    else:
        flow = InstalledAppFlow.from_client_secrets_file(
            'credentials.json', SCOPES)
        creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open('token.json', 'w') as token:
        token.write(creds.to_json())

# %% [markdown]
# # Score Academy
#
# In the section, the user is going to access the scores that have been entered on the spreadsheet `Score Academy`

# %% [markdown]
# Input the link to the Score Academy spreadsheet and retrieve the Spreadsheet ID

# %%
SCORE_ACADEMY_ID = SCORE_ACADEMY_LINK.split(sep='/')[-2]

# %% [markdown]
# Specify the sheet and the cell ranges that is going to be accessed

# %%
# GRADE_RANGE = [f'{NAMA_SHEET}!D:E', f'{NAMA_SHEET}!F:H', f'{NAMA_SHEET}!M:R']
GRADE_RANGE = [f'{NAMA_SHEET}!D:E', f'{NAMA_SHEET}!F:I', f'{NAMA_SHEET}!J:K']

# %% [markdown]
# Call the Google Spreadsheet API and retrieve the values of the ranges that have been specified

# %%
try:
    service = build('sheets', 'v4', credentials=creds)

    sheet = service.spreadsheets().values().batchGet(spreadsheetId=SCORE_ACADEMY_ID,
                                                     ranges=GRADE_RANGE).execute()
    values = sheet.get('valueRanges', [])
        
except HttpError as error:
    print(error)

# %% [markdown]
# Concat the retrieved values as a dataframe

# %%
import pandas as pd

email = pd.DataFrame(values[0].get('values'))
grade_dv = pd.DataFrame(values[1].get('values'))
grade_ml = pd.DataFrame(values[2].get('values'))

df = pd.concat([email, grade_dv, grade_ml], axis=1)
df.columns = df.iloc[0]
df.drop(index=0, inplace=True)
df['Email'] = df['Email'].str.lower() 

df
# Out:
# 0                           Email                Email Classroom P4DA   EDA  \
# 1            alanugroho@gmail.com           alanugroho@gmail.com    0  None
# 2           berlianahar@gmail.com          berlianahar@gmail.com    6  None
# 3          angiegrace35@gmail.com         angiegrace35@gmail.com    6  None
# 4    ihsan.azmi.rabbani@gmail.com   ihsan.azmi.rabbani@gmail.com    6  None
# 5         brenda.thadete@live.com        brenda.thadete@live.com    6  None
# 6              alwanhusni@upi.edu             alwanhusni@upi.edu    0  None
# 7          andrahafizha@gmail.com         andrahafizha@gmail.com    0  None
# 8          adhrian.agie@gmail.com         adhrian.agie@gmail.com    0  None
# 9       arief.marzuki05@gmail.com      arief.marzuki05@gmail.com    0  None
# 10          aryahisma@yahoo.co.id          aryahisma@yahoo.co.id    0  None
# 11          faza.aliyab@gmail.com          faza.aliyab@gmail.com    6  None
# 12      maudy.n.avianti@gmail.com      maudy.n.avianti@gmail.com    0  None
# 13          awqi.gibran@gmail.com          awqi.gibran@gmail.com    0  None
# 14   nicholasnathanael1@gmail.com   nicholasnathanael1@gmail.com    0  None
# 15     santyelisabeth28@gmail.com     santyelisabeth28@gmail.com    0  None
# 16  lazuardi.pramadia@outlook.com  lazuardi.pramadia@outlook.com    6  None
# 17    lintang.nugroho@hotmail.com    lintang.nugroho@hotmail.com    0  None
# 18   shavira.z@massivemusic.co.id   shavira.z@massivemusic.co.id    6  None
# 19          osim.olivia@gmail.com          osim.olivia@gmail.com    6  None
# 20           ardi.azhar@gmail.com           ardi.azhar@gmail.com    0  None
# 21          awalia.irma@gmail.com          awalia.irma@gmail.com    0  None
# 22       fauziasonia.id@gmail.com       fauziasonia.id@gmail.com    0  None
# 23         fenny_martan@yahoo.com         fenny_martan@yahoo.com    0  None
# 24       echberthsumual@gmail.com       echberthsumual@gmail.com    0  None
# 25    jayadidetormentor@gmail.com    jayadidetormentor@gmail.com    6  None
# 26      kikirizqijanuar@gmail.com      kikirizqijanuar@gmail.com    0  None
# 27             lelanovi@gmail.com             lelanovi@gmail.com    6  None
# 28           mpermata83@gmail.com           mpermata83@gmail.com    0  None
# 29       ammaralwandi97@gmail.com       ammaralwandi97@gmail.com    0  None
# 30    rastitiratnasari@icloud.com    rastitiratnasari@icloud.com    0  None
# 31        satyopradana1@gmail.com        satyopradana1@gmail.com    6  None
# 32      theophilos.rico@gmail.com      theophilos.rico@gmail.com    6  None
# 33                                            kinanty@algorit.ma    0  None
#
# 0    DWV   SQL IML 1 IML 2
# 1   None  None   NaN   NaN
# 2   None  None   NaN   NaN
# 3   None  None   NaN   NaN
# 4   None  None   NaN   NaN
# 5   None  None   NaN   NaN
# 6   None  None   NaN   NaN
# 7   None  None   NaN   NaN
# 8   None  None   NaN   NaN
# 9   None  None   NaN   NaN
# 10  None  None   NaN   NaN
# 11  None  None   NaN   NaN
# 12  None  None   NaN   NaN
# 13  None  None   NaN   NaN
# 14  None  None   NaN   NaN
# 15  None  None   NaN   NaN
# 16  None  None   NaN   NaN
# 17  None  None   NaN   NaN
# 18  None  None   NaN   NaN
# 19  None  None   NaN   NaN
# 20  None  None   NaN   NaN
# 21  None  None   NaN   NaN
# 22  None  None   NaN   NaN
# 23  None  None   NaN   NaN
# 24  None  None   NaN   NaN
# 25  None  None   NaN   NaN
# 26  None  None   NaN   NaN
# 27  None  None   NaN   NaN
# 28  None  None   NaN   NaN
# 29  None  None   NaN   NaN
# 30  None  None   NaN   NaN
# 31  None  None   NaN   NaN
# 32  None  None   NaN   NaN
# 33  None  None   NaN   NaN

# %% [markdown]
# # Course
# In this section, the user is going to choose which Google Classroom Course that is going to be accessed

# %% [markdown]
# Call the Google Classroom API to access various methods with user's access from the credential that has been authenticated

# %%
service = build('classroom', 'v1', credentials=creds)

# %% [markdown]
# Use the `courses().list()` method to show a list of the user's courses

# %%
results = service.courses().list(pageSize=20).execute()
courses = results.get('courses', [])

if not courses:
    print('No courses found.')

# Prints the names of the first 5 courses.
print('Courses:')
for course in courses:
    print(f"- {course['name']}")
# Out:
# Courses:
# - Dummy Xion DA
# - Empowering Decisions With Tableau
# - Xion Data Analytics
# - DSS: NIK Data Enrichment and Interactive Visualization
# - In-Depth Data Analysis With Looker Studio
# - Algoritma x Apiary: Mastering Data Science for Product Management
# - [Batch] - [Specialization]
# - Wizard Machine Learning
# - Leveraging Generative AI in Microsoft Excel
# - Data Science for Everyone
# - DSS: Data Science Fundamentals
# - Wizard Data Visualization
# - Policy Making in the Age of AI
# - DSS: Geospatial Data Visualization with Rayshader In R
# - Wizard Data Analytics
# - Data Science for Everyone
# - Data Science for Everyone
# - Business Intelligence Course
# - DSS: Building Large Language Models for Business Applications
# - Vulcan Machine Learning

# %% [markdown]
# Input the course name (**case-insensitive**) that is going to be accessed (Example: `wizard data visualization`). If the course was found, the course's `id` will be retrieved.

# %%
course_input = input("Enter Google Classroom Class Name : ")
course_lowercase = course_input.lower()
course_id = None

for course in courses:
    if course_lowercase == course['name'].lower():
        course_id = course['id']
        break

if course_id == None:
    raise Exception(f"{course_input} course not found")

else:
    print(f'{course_input} found with ID {course_id}')
# Out:
# Dummy Xion DA found with ID 530740179479

# %% [markdown]
# # Quiz
# In this section, the grading process is going to be done using the score retrieved from the spreadsheet

# %% [markdown]
# Input the quiz code (**case-insensitive**) that is going to be accessed. If the quiz was found, the quiz's `id` will be retrieved. **Quiz Input :**
#
#  - `P4DS` : 1. Q: Programming for Data Science (P4DS) & Practical Statistic (PS)
#  - `DV` : 2. Q: Data Visualization (DV)
#  - `IP` : 3. Q: Interactive Plotting (IP)
#  - `RM`
#  - `C1`
#  - `C2`
#  - `UL`
#  - `TS`
#  - `NN`

# %%
from quiz_grader import classcode, quizcode, max_score, quiz_range

service = build('classroom', 'v1', credentials=creds)
response = service.courses().courseWork().list(courseId=course_id).execute()
classworks = response.get('courseWork')

while response.get('nextPageToken'):
    response = service.courses().students().list(courseId=course_id, pageToken = response['nextPageToken']).execute()
    classworks.extend(response.get('courseWork'))

quiz_input = input("Enter Quiz Code: ")
quiz_id = None

for classwork in classworks:
    if classwork['title'] == classcode(quiz_input):
        quiz_id = classwork['id']
        break

if quiz_id == None:
    raise Exception(f"Quiz not found")
else:
    print(f"{classwork['title']} Quiz was found")
# Out:
# 1. Q: Python for Data Analysts (P4DA) Quiz was found

# %% [markdown]
# # Write Score Academy
#
# In this section, the received grade is going to be written in Score Academy

# %%
QUIZ_DF['USER EMAIL'] = QUIZ_DF['USER EMAIL'].str.strip().str.lower()
QUIZ_DF['PASSED STATUS'] = QUIZ_DF['PASSED STATUS'].str.strip().str.lower()
QUIZ_DF = QUIZ_DF[QUIZ_DF['PASSED STATUS'] == "yes"]
QUIZ_DF = QUIZ_DF.drop_duplicates("USER EMAIL")
passed_email = QUIZ_DF["USER EMAIL"]

passed_email
# Out:
# 0             kinanty@algorit.ma
# 1           ghozyaufan@gmail.com
# 3      theophilos.rico@gmail.com
# 4        nadyanaftalia@gmail.com
# 5            wildanziq@gmail.com
#                  ...
# 690       samuelmulia2@gmail.com
# 694              lita@algorit.ma
# 696      adyatama.arga@gmail.com
# 703     davidlimbonggg@gmail.com
# 708       trianinarita@gmail.com
# Name: USER EMAIL, Length: 639, dtype: object

# %%
df.loc[df["Email"].isin(passed_email.values), quizcode(quiz_input)] = max_score(quiz_input)
df.loc[~df["Email"].isin(passed_email.values), quizcode(quiz_input)] = 0

df
# Out:
# 0                           Email                Email Classroom P4DA   EDA  \
# 1            alanugroho@gmail.com           alanugroho@gmail.com    0  None
# 2           berlianahar@gmail.com          berlianahar@gmail.com    6  None
# 3          angiegrace35@gmail.com         angiegrace35@gmail.com    6  None
# 4    ihsan.azmi.rabbani@gmail.com   ihsan.azmi.rabbani@gmail.com    6  None
# 5         brenda.thadete@live.com        brenda.thadete@live.com    6  None
# 6              alwanhusni@upi.edu             alwanhusni@upi.edu    0  None
# 7          andrahafizha@gmail.com         andrahafizha@gmail.com    0  None
# 8          adhrian.agie@gmail.com         adhrian.agie@gmail.com    0  None
# 9       arief.marzuki05@gmail.com      arief.marzuki05@gmail.com    0  None
# 10          aryahisma@yahoo.co.id          aryahisma@yahoo.co.id    0  None
# 11          faza.aliyab@gmail.com          faza.aliyab@gmail.com    6  None
# 12      maudy.n.avianti@gmail.com      maudy.n.avianti@gmail.com    0  None
# 13          awqi.gibran@gmail.com          awqi.gibran@gmail.com    0  None
# 14   nicholasnathanael1@gmail.com   nicholasnathanael1@gmail.com    0  None
# 15     santyelisabeth28@gmail.com     santyelisabeth28@gmail.com    0  None
# 16  lazuardi.pramadia@outlook.com  lazuardi.pramadia@outlook.com    6  None
# 17    lintang.nugroho@hotmail.com    lintang.nugroho@hotmail.com    0  None
# 18   shavira.z@massivemusic.co.id   shavira.z@massivemusic.co.id    6  None
# 19          osim.olivia@gmail.com          osim.olivia@gmail.com    6  None
# 20           ardi.azhar@gmail.com           ardi.azhar@gmail.com    0  None
# 21          awalia.irma@gmail.com          awalia.irma@gmail.com    0  None
# 22       fauziasonia.id@gmail.com       fauziasonia.id@gmail.com    0  None
# 23         fenny_martan@yahoo.com         fenny_martan@yahoo.com    0  None
# 24       echberthsumual@gmail.com       echberthsumual@gmail.com    0  None
# 25    jayadidetormentor@gmail.com    jayadidetormentor@gmail.com    6  None
# 26      kikirizqijanuar@gmail.com      kikirizqijanuar@gmail.com    0  None
# 27             lelanovi@gmail.com             lelanovi@gmail.com    6  None
# 28           mpermata83@gmail.com           mpermata83@gmail.com    0  None
# 29       ammaralwandi97@gmail.com       ammaralwandi97@gmail.com    0  None
# 30    rastitiratnasari@icloud.com    rastitiratnasari@icloud.com    0  None
# 31        satyopradana1@gmail.com        satyopradana1@gmail.com    6  None
# 32      theophilos.rico@gmail.com      theophilos.rico@gmail.com    6  None
# 33                                            kinanty@algorit.ma    0  None
#
# 0    DWV   SQL IML 1 IML 2
# 1   None  None   NaN   NaN
# 2   None  None   NaN   NaN
# 3   None  None   NaN   NaN
# 4   None  None   NaN   NaN
# 5   None  None   NaN   NaN
# 6   None  None   NaN   NaN
# 7   None  None   NaN   NaN
# 8   None  None   NaN   NaN
# 9   None  None   NaN   NaN
# 10  None  None   NaN   NaN
# 11  None  None   NaN   NaN
# 12  None  None   NaN   NaN
# 13  None  None   NaN   NaN
# 14  None  None   NaN   NaN
# 15  None  None   NaN   NaN
# 16  None  None   NaN   NaN
# 17  None  None   NaN   NaN
# 18  None  None   NaN   NaN
# 19  None  None   NaN   NaN
# 20  None  None   NaN   NaN
# 21  None  None   NaN   NaN
# 22  None  None   NaN   NaN
# 23  None  None   NaN   NaN
# 24  None  None   NaN   NaN
# 25  None  None   NaN   NaN
# 26  None  None   NaN   NaN
# 27  None  None   NaN   NaN
# 28  None  None   NaN   NaN
# 29  None  None   NaN   NaN
# 30  None  None   NaN   NaN
# 31  None  None   NaN   NaN
# 32  None  None   NaN   NaN
# 33  None  None   NaN   NaN

# %%
try:
    service = build('sheets', 'v4', credentials=creds)
    
    values = [[x] for x in df[quizcode(quiz_input)].values.tolist()]

    body = {
        'values': values
    }
    result = service.spreadsheets().values().update(
        spreadsheetId=SCORE_ACADEMY_ID, range=f'{NAMA_SHEET}!{quiz_range(quiz_input)}',
        valueInputOption="USER_ENTERED", body=body).execute()
    print(f"{result.get('updatedCells')} cells updated.")

except HttpError as error:
    print(f"An error occurred: {error}")
# Out:
# 47 cells updated.

# %% [markdown]
# ### Draft Grades
#
# Submissions from the chosen quiz are going to be graded as **Draft Grade**

# %% [markdown]
# Use the `courses().courseWork().studentSubmissions().list()` method to store a list of the quiz's submissions

# %%
submissions = []

service = build('classroom', 'v1', credentials=creds)
response = service.courses().courseWork().studentSubmissions().list(
    courseId=course_id,
    courseWorkId=quiz_id).execute()
submissions.extend(response.get('studentSubmissions', []))

while response.get('nextPageToken'):
    response = service.courses().courseWork().studentSubmissions().list(
        courseId=course_id,
        courseWorkId=quiz_id,
        pageToken = response['nextPageToken']).execute()
    submissions.extend(response.get('studentSubmissions'))

# %%
submissions
# Out:
# [{'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg0I9OKDyhYQor_SsbQP',
#   'userId': '103544135692517582217',
#   'creationTime': '2023-11-16T08:07:24.110Z',
#   'updateTime': '2023-11-20T07:09:06.038Z',
#   'state': 'CREATED',
#   'late': True,
#   'draftGrade': 0,
#   'assignedGrade': 0,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NjA2MDgzMTA5Mlpa',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:07:24.092Z',
#      'actorUserId': '103544135692517582217'}},
#    {'gradeHistory': {'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:06.038Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'ASSIGNED_GRADE_POINTS_EARNED_CHANGE'}},
#    {'gradeHistory': {'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:06.038Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'DRAFT_GRADE_POINTS_EARNED_CHANGE'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg0I7eyEkBoQor_SsbQP',
#   'userId': '113844006446860733273',
#   'creationTime': '2023-11-16T08:09:22.743Z',
#   'updateTime': '2023-11-20T07:09:07.537Z',
#   'state': 'CREATED',
#   'late': True,
#   'draftGrade': 0,
#   'assignedGrade': 0,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NzAxMjk1NTc1N1pa',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:09:22.734Z',
#      'actorUserId': '113844006446860733273'}},
#    {'gradeHistory': {'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:07.537Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'ASSIGNED_GRADE_POINTS_EARNED_CHANGE'}},
#    {'gradeHistory': {'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:07.537Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'DRAFT_GRADE_POINTS_EARNED_CHANGE'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg0I4a-UlBwQor_SsbQP',
#   'userId': '113810785755953630319',
#   'creationTime': '2023-11-16T08:07:51.297Z',
#   'updateTime': '2023-11-20T07:09:08.601Z',
#   'state': 'CREATED',
#   'late': True,
#   'draftGrade': 0,
#   'assignedGrade': 0,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NzU1ODQ2OTYwMVpa',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:07:51.282Z',
#      'actorUserId': '113810785755953630319'}},
#    {'gradeHistory': {'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:08.600Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'ASSIGNED_GRADE_POINTS_EARNED_CHANGE'}},
#    {'gradeHistory': {'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:08.601Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'DRAFT_GRADE_POINTS_EARNED_CHANGE'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg0Ik8rcxywQor_SsbQP',
#   'userId': '103462317659258709297',
#   'creationTime': '2023-11-16T08:07:43.908Z',
#   'updateTime': '2023-11-20T07:09:09.723Z',
#   'state': 'CREATED',
#   'late': True,
#   'draftGrade': 4,
#   'assignedGrade': 4,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/MTE5NjE1NzQ2NzVa',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:07:43.886Z',
#      'actorUserId': '103462317659258709297'}},
#    {'gradeHistory': {'pointsEarned': 4,
#      'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:09.723Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'ASSIGNED_GRADE_POINTS_EARNED_CHANGE'}},
#    {'gradeHistory': {'pointsEarned': 4,
#      'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:09.723Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'DRAFT_GRADE_POINTS_EARNED_CHANGE'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg0IlI-P-DcQor_SsbQP',
#   'userId': '117898736442357497369',
#   'creationTime': '2023-11-16T08:08:37.498Z',
#   'updateTime': '2023-11-20T07:09:11.330Z',
#   'state': 'CREATED',
#   'late': True,
#   'draftGrade': 4,
#   'assignedGrade': 4,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/MTUwMTU4NTYwMjBa',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:08:37.473Z',
#      'actorUserId': '117898736442357497369'}},
#    {'gradeHistory': {'pointsEarned': 4,
#      'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:11.330Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'ASSIGNED_GRADE_POINTS_EARNED_CHANGE'}},
#    {'gradeHistory': {'pointsEarned': 4,
#      'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:11.330Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'DRAFT_GRADE_POINTS_EARNED_CHANGE'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg0IpOLwgTkQor_SsbQP',
#   'userId': '106749481412510637626',
#   'creationTime': '2023-11-16T08:07:42.551Z',
#   'updateTime': '2023-11-20T07:09:12.987Z',
#   'state': 'CREATED',
#   'late': True,
#   'draftGrade': 4,
#   'assignedGrade': 4,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/MTUzMDQ3NjU3MzJa',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:07:42.528Z',
#      'actorUserId': '106749481412510637626'}},
#    {'gradeHistory': {'pointsEarned': 4,
#      'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:12.987Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'ASSIGNED_GRADE_POINTS_EARNED_CHANGE'}},
#    {'gradeHistory': {'pointsEarned': 4,
#      'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:12.987Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'DRAFT_GRADE_POINTS_EARNED_CHANGE'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg0I38HTwkoQor_SsbQP',
#   'userId': '117751670129098765183',
#   'creationTime': '2023-11-16T08:07:34.910Z',
#   'updateTime': '2023-11-20T07:09:14.218Z',
#   'state': 'CREATED',
#   'late': True,
#   'draftGrade': 0,
#   'assignedGrade': 0,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/MjAwMDQwMDQwNjNa',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:07:34.903Z',
#      'actorUserId': '117751670129098765183'}},
#    {'gradeHistory': {'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:14.218Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'ASSIGNED_GRADE_POINTS_EARNED_CHANGE'}},
#    {'gradeHistory': {'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:14.218Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'DRAFT_GRADE_POINTS_EARNED_CHANGE'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg0IsYjQh2cQor_SsbQP',
#   'userId': '115359798600456723738',
#   'creationTime': '2023-11-16T08:07:42.010Z',
#   'updateTime': '2023-11-20T07:09:16.015Z',
#   'state': 'RETURNED',
#   'draftGrade': 4,
#   'assignedGrade': 4,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/Mjc2NjQ4NDM4MjVa',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:07:41.986Z',
#      'actorUserId': '115359798600456723738'}},
#    {'stateHistory': {'state': 'TURNED_IN',
#      'stateTimestamp': '2023-11-20T04:30:30.567Z',
#      'actorUserId': '115359798600456723738'}},
#    {'gradeHistory': {'pointsEarned': 4,
#      'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:15.412Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'ASSIGNED_GRADE_POINTS_EARNED_CHANGE'}},
#    {'gradeHistory': {'pointsEarned': 4,
#      'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:15.412Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'DRAFT_GRADE_POINTS_EARNED_CHANGE'}},
#    {'stateHistory': {'state': 'RETURNED',
#      'stateTimestamp': '2023-11-20T07:09:16.015Z',
#      'actorUserId': '107780560222350063089'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg0IvZ_Z0ncQor_SsbQP',
#   'userId': '110827536547407948368',
#   'creationTime': '2023-11-16T08:07:47.597Z',
#   'updateTime': '2023-11-20T07:09:17.154Z',
#   'state': 'CREATED',
#   'late': True,
#   'draftGrade': 0,
#   'assignedGrade': 0,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/MzIxMTcyNDc5MzNa',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:07:47.575Z',
#      'actorUserId': '110827536547407948368'}},
#    {'gradeHistory': {'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:17.154Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'ASSIGNED_GRADE_POINTS_EARNED_CHANGE'}},
#    {'gradeHistory': {'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:17.154Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'DRAFT_GRADE_POINTS_EARNED_CHANGE'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg0IsJmEunsQor_SsbQP',
#   'userId': '104393883243418127509',
#   'creationTime': '2023-11-16T08:07:08.369Z',
#   'updateTime': '2023-11-20T07:09:18.777Z',
#   'state': 'RETURNED',
#   'draftGrade': 4,
#   'assignedGrade': 4,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/MzMxMzkyNjQ2ODha',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:07:08.357Z',
#      'actorUserId': '104393883243418127509'}},
#    {'stateHistory': {'state': 'TURNED_IN',
#      'stateTimestamp': '2023-11-19T16:26:46.773Z',
#      'actorUserId': '104393883243418127509'}},
#    {'gradeHistory': {'pointsEarned': 4,
#      'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:18.206Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'ASSIGNED_GRADE_POINTS_EARNED_CHANGE'}},
#    {'gradeHistory': {'pointsEarned': 4,
#      'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:18.206Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'DRAFT_GRADE_POINTS_EARNED_CHANGE'}},
#    {'stateHistory': {'state': 'RETURNED',
#      'stateTimestamp': '2023-11-20T07:09:18.777Z',
#      'actorUserId': '107780560222350063089'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4IpYH9tZkBEKK_0rG0Dw',
#   'userId': '101186673890023477252',
#   'creationTime': '2023-11-16T08:07:54.776Z',
#   'updateTime': '2023-11-20T07:09:20.767Z',
#   'state': 'RETURNED',
#   'draftGrade': 4,
#   'assignedGrade': 4,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NDExODM4MjE5ODla',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:07:54.756Z',
#      'actorUserId': '101186673890023477252'}},
#    {'stateHistory': {'state': 'TURNED_IN',
#      'stateTimestamp': '2023-11-19T04:51:09.428Z',
#      'actorUserId': '101186673890023477252'}},
#    {'gradeHistory': {'pointsEarned': 4,
#      'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:19.935Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'ASSIGNED_GRADE_POINTS_EARNED_CHANGE'}},
#    {'gradeHistory': {'pointsEarned': 4,
#      'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:19.935Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'DRAFT_GRADE_POINTS_EARNED_CHANGE'}},
#    {'stateHistory': {'state': 'RETURNED',
#      'stateTimestamp': '2023-11-20T07:09:20.767Z',
#      'actorUserId': '107780560222350063089'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4ItOzGlZ8BEKK_0rG0Dw',
#   'userId': '100125000458929926970',
#   'creationTime': '2023-11-16T08:07:44.687Z',
#   'updateTime': '2023-11-20T07:09:22.770Z',
#   'state': 'RETURNED',
#   'draftGrade': 4,
#   'assignedGrade': 4,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NDI3MjY0Mzg0NTJa',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:07:44.679Z',
#      'actorUserId': '100125000458929926970'}},
#    {'stateHistory': {'state': 'TURNED_IN',
#      'stateTimestamp': '2023-11-20T00:47:03.924Z',
#      'actorUserId': '100125000458929926970'}},
#    {'gradeHistory': {'pointsEarned': 4,
#      'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:22.124Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'ASSIGNED_GRADE_POINTS_EARNED_CHANGE'}},
#    {'gradeHistory': {'pointsEarned': 4,
#      'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:22.125Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'DRAFT_GRADE_POINTS_EARNED_CHANGE'}},
#    {'stateHistory': {'state': 'RETURNED',
#      'stateTimestamp': '2023-11-20T07:09:22.770Z',
#      'actorUserId': '107780560222350063089'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4IyKfrm6UBEKK_0rG0Dw',
#   'userId': '104711406500676088970',
#   'creationTime': '2023-11-16T08:07:49.733Z',
#   'updateTime': '2023-11-20T07:09:24.233Z',
#   'state': 'CREATED',
#   'late': True,
#   'draftGrade': 4,
#   'assignedGrade': 4,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NDQzNTAyMzE0OTZa',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:07:49.708Z',
#      'actorUserId': '104711406500676088970'}},
#    {'gradeHistory': {'pointsEarned': 4,
#      'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:24.233Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'ASSIGNED_GRADE_POINTS_EARNED_CHANGE'}},
#    {'gradeHistory': {'pointsEarned': 4,
#      'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:24.233Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'DRAFT_GRADE_POINTS_EARNED_CHANGE'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4InZXB-8YBEKK_0rG0Dw',
#   'userId': '114306989496728968117',
#   'creationTime': '2023-11-16T08:07:18.993Z',
#   'updateTime': '2023-11-20T07:09:25.756Z',
#   'state': 'CREATED',
#   'late': True,
#   'draftGrade': 0,
#   'assignedGrade': 0,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NTM0MDkyMzc2NjFa',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:07:18.971Z',
#      'actorUserId': '114306989496728968117'}},
#    {'gradeHistory': {'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:25.756Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'ASSIGNED_GRADE_POINTS_EARNED_CHANGE'}},
#    {'gradeHistory': {'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:25.756Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'DRAFT_GRADE_POINTS_EARNED_CHANGE'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4IvtT4jccBEKK_0rG0Dw',
#   'userId': '116423163298478532664',
#   'creationTime': '2023-11-16T08:06:24.849Z',
#   'updateTime': '2023-11-20T07:09:26.916Z',
#   'state': 'CREATED',
#   'late': True,
#   'draftGrade': 0,
#   'assignedGrade': 0,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NTM0NDc4OTU2MTRa',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:06:24.841Z',
#      'actorUserId': '116423163298478532664'}},
#    {'gradeHistory': {'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:26.916Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'ASSIGNED_GRADE_POINTS_EARNED_CHANGE'}},
#    {'gradeHistory': {'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:26.916Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'DRAFT_GRADE_POINTS_EARNED_CHANGE'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4IkMnCkscBEKK_0rG0Dw',
#   'userId': '117804810995847761976',
#   'creationTime': '2023-11-16T08:08:41.845Z',
#   'updateTime': '2023-11-20T07:09:28.060Z',
#   'state': 'CREATED',
#   'late': True,
#   'draftGrade': 4,
#   'assignedGrade': 4,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NTM0NTc0OTUxODRa',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:08:41.816Z',
#      'actorUserId': '117804810995847761976'}},
#    {'gradeHistory': {'pointsEarned': 4,
#      'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:28.059Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'ASSIGNED_GRADE_POINTS_EARNED_CHANGE'}},
#    {'gradeHistory': {'pointsEarned': 4,
#      'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:28.060Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'DRAFT_GRADE_POINTS_EARNED_CHANGE'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4I0NmNqMgBEKK_0rG0Dw',
#   'userId': '111009941693864697202',
#   'creationTime': '2023-11-16T08:09:01.456Z',
#   'updateTime': '2023-11-20T07:09:29.496Z',
#   'state': 'CREATED',
#   'late': True,
#   'draftGrade': 0,
#   'assignedGrade': 0,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NTM3NzEyMDE3NDRa',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:09:01.442Z',
#      'actorUserId': '111009941693864697202'}},
#    {'gradeHistory': {'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:29.496Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'ASSIGNED_GRADE_POINTS_EARNED_CHANGE'}},
#    {'gradeHistory': {'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:29.496Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'DRAFT_GRADE_POINTS_EARNED_CHANGE'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4I1eStr8kBEKK_0rG0Dw',
#   'userId': '116232934363625598770',
#   'creationTime': '2023-11-16T08:06:24.174Z',
#   'updateTime': '2023-11-20T07:09:30.714Z',
#   'state': 'CREATED',
#   'late': True,
#   'draftGrade': 0,
#   'assignedGrade': 0,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NTQwNTQ4NDI5NjVa',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:06:24.153Z',
#      'actorUserId': '116232934363625598770'}},
#    {'gradeHistory': {'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:30.714Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'ASSIGNED_GRADE_POINTS_EARNED_CHANGE'}},
#    {'gradeHistory': {'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:30.714Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'DRAFT_GRADE_POINTS_EARNED_CHANGE'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4I5tSs8MoBEKK_0rG0Dw',
#   'userId': '104427765167253416035',
#   'creationTime': '2023-11-16T08:07:39.729Z',
#   'updateTime': '2023-11-20T07:09:31.768Z',
#   'state': 'CREATED',
#   'late': True,
#   'draftGrade': 0,
#   'assignedGrade': 0,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NTQ0NTk1NzQ4ODZa',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:07:39.702Z',
#      'actorUserId': '104427765167253416035'}},
#    {'gradeHistory': {'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:31.768Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'ASSIGNED_GRADE_POINTS_EARNED_CHANGE'}},
#    {'gradeHistory': {'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:31.768Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'DRAFT_GRADE_POINTS_EARNED_CHANGE'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4I-4fDs84BEKK_0rG0Dw',
#   'userId': '108431522349335325350',
#   'creationTime': '2023-11-16T08:06:16.805Z',
#   'updateTime': '2023-11-20T07:09:33.751Z',
#   'state': 'RETURNED',
#   'draftGrade': 4,
#   'assignedGrade': 4,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NTU0MDU3NTc0MzVa',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {'attachments': [{'driveFile': {'id': '1ka1OQKQdiRP8DdpiwH_krGA9ynBE3lWK',
#       'title': 'quiz_fz.Rmd',
#       'alternateLink': 'https://drive.google.com/file/d/1ka1OQKQdiRP8DdpiwH_krGA9ynBE3lWK/view?usp=drive_web'}}]},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:06:16.791Z',
#      'actorUserId': '108431522349335325350'}},
#    {'stateHistory': {'state': 'TURNED_IN',
#      'stateTimestamp': '2023-11-17T08:07:22.244Z',
#      'actorUserId': '108431522349335325350'}},
#    {'gradeHistory': {'pointsEarned': 4,
#      'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:32.947Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'ASSIGNED_GRADE_POINTS_EARNED_CHANGE'}},
#    {'gradeHistory': {'pointsEarned': 4,
#      'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:32.947Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'DRAFT_GRADE_POINTS_EARNED_CHANGE'}},
#    {'stateHistory': {'state': 'RETURNED',
#      'stateTimestamp': '2023-11-20T07:09:33.751Z',
#      'actorUserId': '107780560222350063089'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4Iiq2S_P0BEKK_0rG0Dw',
#   'userId': '114909086121040934882',
#   'creationTime': '2023-11-16T08:08:12.049Z',
#   'updateTime': '2023-11-20T07:09:36.528Z',
#   'state': 'RETURNED',
#   'draftGrade': 4,
#   'assignedGrade': 4,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NjgxNzQ1MTc4OTha',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:08:12.030Z',
#      'actorUserId': '114909086121040934882'}},
#    {'stateHistory': {'state': 'TURNED_IN',
#      'stateTimestamp': '2023-11-19T15:43:07.134Z',
#      'actorUserId': '114909086121040934882'}},
#    {'gradeHistory': {'pointsEarned': 4,
#      'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:35.877Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'ASSIGNED_GRADE_POINTS_EARNED_CHANGE'}},
#    {'gradeHistory': {'pointsEarned': 4,
#      'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:35.877Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'DRAFT_GRADE_POINTS_EARNED_CHANGE'}},
#    {'stateHistory': {'state': 'RETURNED',
#      'stateTimestamp': '2023-11-20T07:09:36.528Z',
#      'actorUserId': '107780560222350063089'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4Iq8i3ndYCEKK_0rG0Dw',
#   'userId': '101836608817475262392',
#   'creationTime': '2023-11-16T08:10:38.550Z',
#   'updateTime': '2023-11-20T07:09:38.130Z',
#   'state': 'RETURNED',
#   'draftGrade': 4,
#   'assignedGrade': 4,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/OTE4NjY2NTM3Mzla',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:10:38.538Z',
#      'actorUserId': '101836608817475262392'}},
#    {'stateHistory': {'state': 'TURNED_IN',
#      'stateTimestamp': '2023-11-19T05:17:04.698Z',
#      'actorUserId': '101836608817475262392'}},
#    {'gradeHistory': {'pointsEarned': 4,
#      'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:37.644Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'ASSIGNED_GRADE_POINTS_EARNED_CHANGE'}},
#    {'gradeHistory': {'pointsEarned': 4,
#      'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:37.644Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'DRAFT_GRADE_POINTS_EARNED_CHANGE'}},
#    {'stateHistory': {'state': 'RETURNED',
#      'stateTimestamp': '2023-11-20T07:09:38.130Z',
#      'actorUserId': '107780560222350063089'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4IpMq1yboDEKK_0rG0Dw',
#   'userId': '117900542101325870087',
#   'creationTime': '2023-11-16T08:06:56.776Z',
#   'updateTime': '2023-11-20T07:09:39.056Z',
#   'state': 'CREATED',
#   'late': True,
#   'draftGrade': 0,
#   'assignedGrade': 0,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/MTE4ODAyNDQxNTA4',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:06:56.765Z',
#      'actorUserId': '117900542101325870087'}},
#    {'gradeHistory': {'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:39.056Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'ASSIGNED_GRADE_POINTS_EARNED_CHANGE'}},
#    {'gradeHistory': {'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:39.056Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'DRAFT_GRADE_POINTS_EARNED_CHANGE'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4I3OfwvfEFEKK_0rG0Dw',
#   'userId': '114828602169503541400',
#   'creationTime': '2023-11-16T08:08:14.746Z',
#   'updateTime': '2023-11-20T07:09:40.569Z',
#   'state': 'RETURNED',
#   'draftGrade': 4,
#   'assignedGrade': 4,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/MjAyMjYxNjcyOTI0',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:08:14.733Z',
#      'actorUserId': '114828602169503541400'}},
#    {'stateHistory': {'state': 'TURNED_IN',
#      'stateTimestamp': '2023-11-20T02:31:25.306Z',
#      'actorUserId': '114828602169503541400'}},
#    {'gradeHistory': {'pointsEarned': 4,
#      'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:40.078Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'ASSIGNED_GRADE_POINTS_EARNED_CHANGE'}},
#    {'gradeHistory': {'pointsEarned': 4,
#      'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:40.078Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'DRAFT_GRADE_POINTS_EARNED_CHANGE'}},
#    {'stateHistory': {'state': 'RETURNED',
#      'stateTimestamp': '2023-11-20T07:09:40.569Z',
#      'actorUserId': '107780560222350063089'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4IlsnOzd8IEKK_0rG0Dw',
#   'userId': '104047168932570820836',
#   'creationTime': '2023-11-16T08:08:07.512Z',
#   'updateTime': '2023-11-16T08:08:07.482Z',
#   'state': 'CREATED',
#   'late': True,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/MzAwNTQyMDQzMjg2',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:08:07.482Z',
#      'actorUserId': '104047168932570820836'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4I09Pm4rwJEKK_0rG0Dw',
#   'userId': '116085810387530002905',
#   'creationTime': '2023-11-16T08:06:45.907Z',
#   'updateTime': '2023-11-16T08:06:45.898Z',
#   'state': 'CREATED',
#   'late': True,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/MzI1NTUwOTc1NDQz',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:06:45.898Z',
#      'actorUserId': '116085810387530002905'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4IwZWn86YNEKK_0rG0Dw',
#   'userId': '100449232275610443279',
#   'creationTime': '2023-11-16T08:06:47.726Z',
#   'updateTime': '2023-11-20T07:09:43.244Z',
#   'state': 'RETURNED',
#   'draftGrade': 4,
#   'assignedGrade': 4,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NDU3MTE4OTYwMzIx',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:06:47.718Z',
#      'actorUserId': '100449232275610443279'}},
#    {'stateHistory': {'state': 'TURNED_IN',
#      'stateTimestamp': '2023-11-19T13:11:43.880Z',
#      'actorUserId': '100449232275610443279'}},
#    {'gradeHistory': {'pointsEarned': 4,
#      'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:42.693Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'ASSIGNED_GRADE_POINTS_EARNED_CHANGE'}},
#    {'gradeHistory': {'pointsEarned': 4,
#      'maxPoints': 4,
#      'gradeTimestamp': '2023-11-20T07:09:42.693Z',
#      'actorUserId': '107780560222350063089',
#      'gradeChangeType': 'DRAFT_GRADE_POINTS_EARNED_CHANGE'}},
#    {'stateHistory': {'state': 'RETURNED',
#      'stateTimestamp': '2023-11-20T07:09:43.244Z',
#      'actorUserId': '107780560222350063089'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4IotG_yfcNEKK_0rG0Dw',
#   'userId': '106955206372973362710',
#   'creationTime': '2023-11-16T08:06:34.185Z',
#   'updateTime': '2023-11-16T08:06:34.176Z',
#   'state': 'CREATED',
#   'late': True,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NDc4Nzc0NTUyNzM4',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:06:34.176Z',
#      'actorUserId': '106955206372973362710'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4IvIOIo8AOEKK_0rG0Dw',
#   'userId': '100623270097782270205',
#   'creationTime': '2023-11-16T08:06:12.885Z',
#   'updateTime': '2023-11-16T08:06:12.867Z',
#   'state': 'CREATED',
#   'late': True,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NDk4Mjg5NzM4MTcy',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:06:12.867Z',
#      'actorUserId': '100623270097782270205'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4I18HQo8AOEKK_0rG0Dw',
#   'userId': '104958462378048332898',
#   'creationTime': '2023-11-16T08:07:27.566Z',
#   'updateTime': '2023-11-16T08:07:27.534Z',
#   'state': 'CREATED',
#   'late': True,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NDk4MjkwOTI1Nzgz',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:07:27.534Z',
#      'actorUserId': '104958462378048332898'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4I87z4l9wOEKK_0rG0Dw',
#   'userId': '105250506097979753968',
#   'creationTime': '2023-11-16T08:08:38.475Z',
#   'updateTime': '2023-11-16T08:08:38.454Z',
#   'state': 'CREATED',
#   'late': True,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NTA1NzgyNjA3NDc1',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:08:38.454Z',
#      'actorUserId': '105250506097979753968'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4IqPuXzPUOEKK_0rG0Dw',
#   'userId': '108931938371256497403',
#   'creationTime': '2023-11-16T08:06:07.083Z',
#   'updateTime': '2023-11-16T08:06:07.055Z',
#   'state': 'CREATED',
#   'late': True,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NTEyNjAzMDYxNjcy',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:06:07.055Z',
#      'actorUserId': '108931938371256497403'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4ItZn5gooPEKK_0rG0Dw',
#   'userId': '107716321960383843386',
#   'creationTime': '2023-11-16T08:06:35.992Z',
#   'updateTime': '2023-11-16T08:06:35.980Z',
#   'state': 'CREATED',
#   'late': True,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NTE4MDg2NjEwMTAx',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:06:35.979Z',
#      'actorUserId': '107716321960383843386'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4IsqfcoosPEKK_0rG0Dw',
#   'userId': '105832313269015476129',
#   'creationTime': '2023-11-16T08:07:11.054Z',
#   'updateTime': '2023-11-16T08:07:11.029Z',
#   'state': 'CREATED',
#   'late': True,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NTE4NDIxNjgxMDc0',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:07:11.029Z',
#      'actorUserId': '105832313269015476129'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4I9cfHiJwPEKK_0rG0Dw',
#   'userId': '111368079668371536024',
#   'creationTime': '2023-11-16T08:07:41.181Z',
#   'updateTime': '2023-11-17T00:57:53.932Z',
#   'state': 'TURNED_IN',
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NTIyOTMwMjE3OTcz',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:07:41.158Z',
#      'actorUserId': '111368079668371536024'}},
#    {'stateHistory': {'state': 'TURNED_IN',
#      'stateTimestamp': '2023-11-17T00:57:53.932Z',
#      'actorUserId': '111368079668371536024'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4I-4Gyl5wPEKK_0rG0Dw',
#   'userId': '115459424914573422315',
#   'creationTime': '2023-11-16T08:06:36.084Z',
#   'updateTime': '2023-11-20T05:41:05.423Z',
#   'state': 'TURNED_IN',
#   'late': True,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NTIyOTYxMzIyMjM1',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:06:36.071Z',
#      'actorUserId': '115459424914573422315'}},
#    {'stateHistory': {'state': 'TURNED_IN',
#      'stateTimestamp': '2023-11-20T05:41:05.423Z',
#      'actorUserId': '115459424914573422315'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4I2NOJmJwPEKK_0rG0Dw',
#   'userId': '105474182087478198182',
#   'creationTime': '2023-11-16T08:06:26.027Z',
#   'updateTime': '2023-11-19T14:06:03.132Z',
#   'state': 'TURNED_IN',
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NTIyOTYyNzU4MTA0',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {'attachments': [{'driveFile': {'id': '1G-zqdxdvPXP6UwSDS_scsTCsuhly9R7L',
#       'title': 'quiz_indo lel.Rmd',
#       'alternateLink': 'https://drive.google.com/file/d/1G-zqdxdvPXP6UwSDS_scsTCsuhly9R7L/view?usp=drive_web'}}]},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:06:25.999Z',
#      'actorUserId': '105474182087478198182'}},
#    {'stateHistory': {'state': 'TURNED_IN',
#      'stateTimestamp': '2023-11-19T14:06:03.132Z',
#      'actorUserId': '105474182087478198182'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4IrKb_jZ0PEKK_0rG0Dw',
#   'userId': '104914194777100418266',
#   'creationTime': '2023-11-16T08:07:52.994Z',
#   'updateTime': '2023-11-19T18:12:05.092Z',
#   'state': 'TURNED_IN',
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NTIzMjEwMDUyMzk2',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {'attachments': [{'driveFile': {'id': '11ykhBgben1WotSK2IFQuJpFxOQsIKTtb',
#       'title': 'ML.W6 - Sasmita-Bagus-Eko-Riyanto-Neural-Network-and-Deep-Learning-Neural-Network-and-Deep-Learning-certificate-Algoritma-Data-Science-School.pdf',
#       'alternateLink': 'https://drive.google.com/file/d/11ykhBgben1WotSK2IFQuJpFxOQsIKTtb/view?usp=drive_web',
#       'thumbnailUrl': 'https://lh3.googleusercontent.com/drive-storage/AKHj6E6JEFXOWukDrUeDNlUhd6pEN843_L3BS1TB0c6xohaeXvLe-LDNOpENrvdVu-FzHd7XPJa_yG-lQF1mWofH9_p96ybYBqaVL_lb7EokKg=s200'}}]},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:07:52.976Z',
#      'actorUserId': '104914194777100418266'}},
#    {'stateHistory': {'state': 'TURNED_IN',
#      'stateTimestamp': '2023-11-19T18:12:05.092Z',
#      'actorUserId': '104914194777100418266'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4I6PTRrJ0PEKK_0rG0Dw',
#   'userId': '109461722307490135767',
#   'creationTime': '2023-11-16T08:07:57.852Z',
#   'updateTime': '2023-11-17T13:01:06.199Z',
#   'state': 'TURNED_IN',
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NTIzMjc0MzIwNDg4',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {'attachments': [{'driveFile': {'id': '18bebSqUkUakWH60Ju248dCUIBP6uuUDY',
#       'title': 'quiznn',
#       'alternateLink': 'https://drive.google.com/drive/folders/18bebSqUkUakWH60Ju248dCUIBP6uuUDY'}}]},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:07:57.835Z',
#      'actorUserId': '109461722307490135767'}},
#    {'stateHistory': {'state': 'TURNED_IN',
#      'stateTimestamp': '2023-11-17T13:01:06.199Z',
#      'actorUserId': '109461722307490135767'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4I5I6y750PEKK_0rG0Dw',
#   'userId': '105743414091014001813',
#   'creationTime': '2023-11-16T08:06:53.499Z',
#   'updateTime': '2023-11-20T04:32:41.525Z',
#   'state': 'TURNED_IN',
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NTIzNDE0MzA4NzA4',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {'attachments': [{'driveFile': {'id': '1EB4szNfVnfBpgvvj9L4So7UIOm_8CLQx',
#       'title': 'quiz_9_nn-main.zip',
#       'alternateLink': 'https://drive.google.com/file/d/1EB4szNfVnfBpgvvj9L4So7UIOm_8CLQx/view?usp=drive_web'}}]},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:06:53.472Z',
#      'actorUserId': '105743414091014001813'}},
#    {'stateHistory': {'state': 'TURNED_IN',
#      'stateTimestamp': '2023-11-20T04:32:41.525Z',
#      'actorUserId': '105743414091014001813'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4I59_a4asPEKK_0rG0Dw',
#   'userId': '114876575994806994080',
#   'creationTime': '2023-11-16T08:08:45.529Z',
#   'updateTime': '2023-11-16T08:08:45.496Z',
#   'state': 'CREATED',
#   'late': True,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NTI3MTQzNzEwNjk1',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:08:45.496Z',
#      'actorUserId': '114876575994806994080'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4I8Mrgh_kREKK_0rG0Dw',
#   'userId': '110885052581583477770',
#   'creationTime': '2023-11-16T08:09:40.635Z',
#   'updateTime': '2023-11-19T19:32:57.355Z',
#   'state': 'TURNED_IN',
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NjE2NjEyNTA0OTQ0',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:09:40.615Z',
#      'actorUserId': '110885052581583477770'}},
#    {'stateHistory': {'state': 'TURNED_IN',
#      'stateTimestamp': '2023-11-19T19:32:57.355Z',
#      'actorUserId': '110885052581583477770'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4It826yvoREKK_0rG0Dw',
#   'userId': '100684685567880437632',
#   'creationTime': '2023-11-16T08:06:49.008Z',
#   'updateTime': '2023-11-19T09:07:38.265Z',
#   'state': 'TURNED_IN',
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NjE3MDIwODI3MzE5',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:06:48.980Z',
#      'actorUserId': '100684685567880437632'}},
#    {'stateHistory': {'state': 'TURNED_IN',
#      'stateTimestamp': '2023-11-19T09:07:38.265Z',
#      'actorUserId': '100684685567880437632'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4IxrvGzfoREKK_0rG0Dw',
#   'userId': '117250599203063249633',
#   'creationTime': '2023-11-16T08:06:07.791Z',
#   'updateTime': '2023-11-16T08:06:07.776Z',
#   'state': 'CREATED',
#   'late': True,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NjE3MDI3MzEzMDk0',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:06:07.776Z',
#      'actorUserId': '117250599203063249633'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4ItsDJzfoREKK_0rG0Dw',
#   'userId': '110583192808813078276',
#   'creationTime': '2023-11-16T08:07:53.119Z',
#   'updateTime': '2023-11-17T07:35:52.869Z',
#   'state': 'TURNED_IN',
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NjE3MDI3MzYyODcw',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:07:53.105Z',
#      'actorUserId': '110583192808813078276'}},
#    {'stateHistory': {'state': 'TURNED_IN',
#      'stateTimestamp': '2023-11-17T07:35:52.869Z',
#      'actorUserId': '110583192808813078276'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4I5Zqd-vsREKK_0rG0Dw',
#   'userId': '103915148544040430413',
#   'creationTime': '2023-11-16T08:08:54.174Z',
#   'updateTime': '2023-11-16T08:08:54.162Z',
#   'state': 'CREATED',
#   'late': True,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NjE3Mzg5NDQ0NDUz',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:08:54.162Z',
#      'actorUserId': '103915148544040430413'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4Iw4yXivwREKK_0rG0Dw',
#   'userId': '107179300110130831585',
#   'creationTime': '2023-11-16T08:07:07.183Z',
#   'updateTime': '2023-11-20T01:40:45.910Z',
#   'state': 'TURNED_IN',
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NjE3NDIyODk4NzU1',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:07:07.160Z',
#      'actorUserId': '107179300110130831585'}},
#    {'stateHistory': {'state': 'TURNED_IN',
#      'stateTimestamp': '2023-11-20T01:40:45.910Z',
#      'actorUserId': '107179300110130831585'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4Ioe7ZivwREKK_0rG0Dw',
#   'userId': '108202777300275221639',
#   'creationTime': '2023-11-16T08:09:06.679Z',
#   'updateTime': '2023-11-16T08:09:06.654Z',
#   'state': 'CREATED',
#   'late': True,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NjE3NDIzOTkyNjA5',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:09:06.654Z',
#      'actorUserId': '108202777300275221639'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4IiomczI4SEKK_0rG0Dw',
#   'userId': '108797507179264859262',
#   'creationTime': '2023-11-16T08:09:28.558Z',
#   'updateTime': '2023-11-16T08:09:28.545Z',
#   'state': 'CREATED',
#   'late': True,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NjIyMzkzMjMwNDc0',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:09:28.545Z',
#      'actorUserId': '108797507179264859262'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4I6KiXxZASEKK_0rG0Dw',
#   'userId': '101669722690483888131',
#   'creationTime': '2023-11-16T08:09:25.475Z',
#   'updateTime': '2023-11-20T04:06:26.891Z',
#   'state': 'TURNED_IN',
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NjIyOTE1MzQzNDY0',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {'attachments': [{'driveFile': {'id': '1mH4U6C8t6gRJEeK2DDT-ZccPSBfAkdnF',
#       'title': 'quiz_indo.Rmd',
#       'alternateLink': 'https://drive.google.com/file/d/1mH4U6C8t6gRJEeK2DDT-ZccPSBfAkdnF/view?usp=drive_web'}}]},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:09:25.450Z',
#      'actorUserId': '101669722690483888131'}},
#    {'stateHistory': {'state': 'TURNED_IN',
#      'stateTimestamp': '2023-11-20T04:06:26.891Z',
#      'actorUserId': '101669722690483888131'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4Iv8jL4JESEKK_0rG0Dw',
#   'userId': '117700990742414723029',
#   'creationTime': '2023-11-16T08:09:36.974Z',
#   'updateTime': '2023-11-16T08:09:36.956Z',
#   'state': 'CREATED',
#   'late': True,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NjIzMjQxMjU4MDQ3',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:09:36.956Z',
#      'actorUserId': '117700990742414723029'}}]},
#  {'courseId': '529458923369',
#   'courseWorkId': '529458831266',
#   'id': 'Cg4I3b_C4KsSEKK_0rG0Dw',
#   'userId': '107495587086392122457',
#   'creationTime': '2023-11-16T08:06:45.832Z',
#   'updateTime': '2023-11-16T08:06:45.812Z',
#   'state': 'CREATED',
#   'late': True,
#   'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NjMwMjIwNDMxMzI1',
#   'courseWorkType': 'ASSIGNMENT',
#   'assignmentSubmission': {},
#   'associatedWithDeveloper': True,
#   'submissionHistory': [{'stateHistory': {'state': 'CREATED',
#      'stateTimestamp': '2023-11-16T08:06:45.812Z',
#      'actorUserId': '107495587086392122457'}}]}]

# %%
for i in submissions:
    if i['userId'] == "105250506097979753968":
        print(i)
# Out:
# {'courseId': '529458923369', 'courseWorkId': '529458831266', 'id': 'Cg4I87z4l9wOEKK_0rG0Dw', 'userId': '105250506097979753968', 'creationTime': '2023-11-16T08:08:38.475Z', 'updateTime': '2023-11-16T08:08:38.454Z', 'state': 'CREATED', 'late': True, 'alternateLink': 'https://classroom.google.com/c/NTI5NDU4OTIzMzY5/a/NTI5NDU4ODMxMjY2/submissions/by-status/and-sort-last-name/student/NTA1NzgyNjA3NDc1', 'courseWorkType': 'ASSIGNMENT', 'assignmentSubmission': {}, 'associatedWithDeveloper': True, 'submissionHistory': [{'stateHistory': {'state': 'CREATED', 'stateTimestamp': '2023-11-16T08:08:38.454Z', 'actorUserId': '105250506097979753968'}}]}

# %%
service.courses().students().get(courseId=course_id, userId="103544135692517582217").execute()
# Out:
# {'courseId': '621398536690',
#  'userId': '103544135692517582217',
#  'profile': {'id': '103544135692517582217',
#   'name': {'givenName': 'Nissa',
#    'familyName': 'Corlidea',
#    'fullName': 'Nissa Corlidea'},
#   'emailAddress': 'ncorlidea99@gmail.com',
#   'permissions': [{'permission': 'CREATE_COURSE'}]}}

# %% [markdown]
# All the stored submission are graded as draft in accordance with the student's e-mail in the Google Classroom using `courses().courseWork().studentSubmissions().patch()` method

# %%
from assets import quizcode

draft = []
quiz_code = quizcode(quiz_input)

for submission in submissions:
  # Retrieve student's email
  submission_profile = service.courses().students().get(courseId=course_id, userId=submission['userId']).execute()
  student_df = df.loc[df['Email Classroom'] == submission_profile['profile']['emailAddress']]
  
  # Retrieve student's grade
  if not student_df.empty:
    if isinstance(student_df[quiz_code].values[0], int) or student_df[quiz_code].values[0].isnumeric():
      submission_grade = student_df[quiz_code].values[0]
    else:
      print(f"WARNING: {submission_profile['profile']['name']['fullName']} ({submission_profile['profile']['emailAddress']}) has no grade")
      draft.append([submission_profile['profile']['name']['fullName'], submission_profile['profile']['emailAddress'], None, "NO GRADE"])
      continue      
  else:
    print(f"WARNING: {submission_profile['profile']['name']['fullName']} ({submission_profile['profile']['emailAddress']}) was not found")
    draft.append([submission_profile['profile']['name']['fullName'], submission_profile['profile']['emailAddress'], None, "NOT FOUND"])
    continue

  # Grade the submission as draftGrade
  studentSubmission = {
    'draftGrade': str(submission_grade),
    'assignedGrade': str(submission_grade)
  }

  response = service.courses().courseWork().studentSubmissions().patch(
      courseId=course_id,
      courseWorkId=classwork['id'],
      id=submission['id'],
      updateMask='assignedGrade,draftGrade',
      body = studentSubmission).execute()
  
  if submission['state'] == 'TURNED_IN':
      response = service.courses().courseWork().studentSubmissions().return_(
          courseId=course_id,
          courseWorkId=classwork['id'],
          id=submission['id']).execute()
  
  draft.append([submission_profile['profile']['name']['fullName'], submission_profile['profile']['emailAddress'], submission_grade, "GRADED"])

draft_df = pd.DataFrame(draft, columns=['Name', 'Email Classroom', 'Grade', 'Status'])
draft_df.sort_values('Status')
# Out:
# WARNING: Anastasya Algoritma (anastasya@algorit.ma) was not found
# WARNING: Sari Nurfiani (sari@algorit.ma) was not found
# WARNING: Algoritma Night (algostudentnight1@gmail.com) was not found
# WARNING: Geolana Wijayakusumah (geolana@algorit.ma) was not found
# WARNING: Mohammad De Syaeful (syaeful@algorit.ma) was not found
# WARNING: Charisma Omega Nafu (charisma@algorit.ma) was not found
# WARNING: Algoritma Day (algostudentday@gmail.com) was not found
# WARNING: Azzahra Putri Triarto (zahra@algorit.ma) was not found
# WARNING: Irsyad Akmala Mukhtar (irsyad.mukhtar@gmail.com) was not found
# WARNING: Famy Kurnia (famykurnia@gmail.com) was not found
# WARNING: rcaesario (idxriski.caesario@gmail.com) was not found
#                              Name                Email Classroom  Grade  \
# 0                  Nissa Corlidea          ncorlidea99@gmail.com    1.0
# 25                   Dimas Aditya        senddimasadit@gmail.com    0.0
# 27             Jayadi butar-butar    jayadidetormentor@gmail.com    1.0
# 53                   Louis Sirait         louis.sirait@gmail.com    0.0
# 52                  satyo pradana        satyopradana1@gmail.com    1.0
# 51                  Charles Kambu        kambu.charles@gmail.com    1.0
# 50                Husna Aydadenta              haydnta@gmail.com    0.0
# 33              Nia Dewi Nofianti    niadewinofianti18@gmail.com    1.0
# 34                   Audi Chandra        audichandra94@gmail.com    1.0
# 35         Farhan Zhafar Ramadhan    zhafarfarhan.work@gmail.com    1.0
# 36                      Lela Novi             LelaNovi@gmail.com    1.0
# 37                 Riyan Sasmytha        riyansasmytha@gmail.com    1.0
# 38                 Luthfi Pratama           lhpratama2@gmail.com    1.0
# 39                  Pandu Working    pandukukunforwork@gmail.com    1.0
# 48                   Calvin Gozal          calvingozal@gmail.com    0.0
# 41                  Melissa Rusli         melissa.offc@gmail.com    1.0
# 42            Taufan Anggoro Adhi           tf.anggoro@gmail.com    1.0
# 43                Ranno Chairandy      ranno.chairandy@gmail.com    1.0
# 44                Hendry Julianto        hendrychai.id@gmail.com    1.0
# 45                      Brenda Th       brenda.thadete@gmail.com    1.0
# 24                Fransiska Pinem     jesintafransiska@gmail.com    1.0
# 46            Fathiyyah Maryufani  fathiyyah.maryufani@gmail.com    1.0
# 23                   Fenny Martan          martanfenny@gmail.com    0.0
# 21                Bagus Pramudito     baguspramudito92@gmail.com    1.0
# 1        Cak Mustafa (cakmustafa)           cakmustafa@gmail.com    0.0
# 2             Shavira Zhalsabilla         szhalsabilla@gmail.com    1.0
# 3                             Dea        trishna.fadea@gmail.com    0.0
# 4                    Albertus MPP          albertusmpp@gmail.com    1.0
# 5                   Taufiq Rahman            taufiq234@gmail.com    1.0
# 6         Pramadia Adhie Lazuardi    pramadia.lazuardi@gmail.com    1.0
# 7                Bintang Setyawan          binsetyawan@gmail.com    0.0
# 8                    Fajar khamim         fajarkhamim6@gmail.com    0.0
# 9           Grace Angela Sutantya         angiegrace35@gmail.com    1.0
# 10              Danadyaksa Wijaya     danadyaksawijaya@gmail.com    1.0
# 22                gustaf yulianto       gustafyulianto@gmail.com    0.0
# 11               Berliana Harahap          berlianahar@gmail.com    1.0
# 13      Theophilos Adalrico Abadi      theophilos.rico@gmail.com    1.0
# 14                 Ellen Setiawan     vinsensiaellen10@gmail.com    1.0
# 15            Anas Fauzan Baletti         fafafauzan30@gmail.com    1.0
# 16  Ihsan Azmi Rabbani (HeatAced)   ihsan.azmi.rabbani@gmail.com    1.0
# 17                 Nadya Naftalia        nadyanaftalia@gmail.com    1.0
# 18              Ghozy Abror Aufan           ghozyaufan@gmail.com    1.0
# 19                     Faza Aliya          Faza.AliyaB@gmail.com    1.0
# 20                     Olivia Sim          osim.olivia@gmail.com    1.0
# 12                    ridha rahmi          rahmi.ridha@gmail.com    1.0
# 47                  Wildan Hadziq            wildanziq@gmail.com    1.0
# 49          Azzahra Putri Triarto               zahra@algorit.ma    NaN
# 54          Irsyad Akmala Mukhtar       irsyad.mukhtar@gmail.com    NaN
# 28                  Sari Nurfiani                sari@algorit.ma    NaN
# 32            Charisma Omega Nafu            charisma@algorit.ma    NaN
# 31            Mohammad De Syaeful             syaeful@algorit.ma    NaN
# 30          Geolana Wijayakusumah             geolana@algorit.ma    NaN
# 29                Algoritma Night    algostudentnight1@gmail.com    NaN
# 55                    Famy Kurnia           famykurnia@gmail.com    NaN
# 26            Anastasya Algoritma           anastasya@algorit.ma    NaN
# 40                  Algoritma Day       algostudentday@gmail.com    NaN
# 56                      rcaesario    idxriski.caesario@gmail.com    NaN
#
#        Status
# 0      GRADED
# 25     GRADED
# 27     GRADED
# 53     GRADED
# 52     GRADED
# 51     GRADED
# 50     GRADED
# 33     GRADED
# 34     GRADED
# 35     GRADED
# 36     GRADED
# 37     GRADED
# 38     GRADED
# 39     GRADED
# 48     GRADED
# 41     GRADED
# 42     GRADED
# 43     GRADED
# 44     GRADED
# 45     GRADED
# 24     GRADED
# 46     GRADED
# 23     GRADED
# 21     GRADED
# 1      GRADED
# 2      GRADED
# 3      GRADED
# 4      GRADED
# 5      GRADED
# 6      GRADED
# 7      GRADED
# 8      GRADED
# 9      GRADED
# 10     GRADED
# 22     GRADED
# 11     GRADED
# 13     GRADED
# 14     GRADED
# 15     GRADED
# 16     GRADED
# 17     GRADED
# 18     GRADED
# 19     GRADED
# 20     GRADED
# 12     GRADED
# 47     GRADED
# 49  NOT FOUND
# 54  NOT FOUND
# 28  NOT FOUND
# 32  NOT FOUND
# 31  NOT FOUND
# 30  NOT FOUND
# 29  NOT FOUND
# 55  NOT FOUND
# 26  NOT FOUND
# 40  NOT FOUND
# 56  NOT FOUND

# %% [markdown]
# # Testing

# %% [markdown]
# for submission in submissions:
#     studentSubmission = {
#         'draftGrade': str(1),
#         'assignedGrade': str(1)
#     }
#
#     response = service.courses().courseWork().studentSubmissions().patch(
#         courseId=course_id,
#         courseWorkId=classwork['id'],
#         id=submission['id'],
#         updateMask='assignedGrade,draftGrade',
#         body = studentSubmission).execute()
#
#     if submission['state'] == 'TURNED_IN':
#         response = service.courses().courseWork().studentSubmissions().return_(
#             courseId=course_id,
#             courseWorkId=classwork['id'],
#             id=submission['id']).execute()

# %% [markdown]
# try:
#     for submission in submissions:
#         studentSubmission = {
#             'draftGrade': str(2),
#             'assignedGrade': str(2)
#         }
#
#         response = service.courses().courseWork().studentSubmissions().return_(
#             courseId=course_id,
#             courseWorkId=classwork['id'],
#             id=submission['id']).execute()
#
# except HttpError as error:
#     print(error)
